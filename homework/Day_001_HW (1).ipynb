# %% [markdown]
# [Hw1]
# 求mean squared error

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y,yp):
    """
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y-yp))/len(y)
    return mae

def mean_squared_error(y,yp):
    mse = MSE = sum((y-yp)**2)/len(y)
    return mse

# %%
#y=wx+b
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label= 'data point')
plt.title("Assume we have data point")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" %(MSE))
print("The Mean absolute error is %.3f" %(MAE))
# Out:
# The Mean squared error is 235.857
# The Mean absolute error is 12.642

# %% [markdown]
# [HW2]
# https://www.kaggle.com/ahmadjaved097/analysis-of-top-50-spotify-songs
#
# 1.你選的這組資料為何重要
#     Analysis of Top 50 Spotify Songs
#     我認為此項資料分析包含以下兩個重要面向:
#     (1)企業的核⼼問題-spotify
#        對於spotify音樂串流平台,需要知道大眾的普遍喜好，有助於推薦給顧客的音樂，讓顧客更願意買單，以及上架音樂的選擇。
#     (2)影響政策方向-音樂產業
#        對於音樂製作人來說，他們可以了解現今流行，製作符合流行又能保有自身風格的音樂。
#
# 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     spotify 提供top songs，透過用戶下載播放流量紀錄
#     Billboard 提供歌曲相關資訊，透過分析歌曲相關性質紀錄
#
# 3.蒐集而來的資料型態為何
#     非結構化資料 - 音訊(分貝、長度etc)
# 4.這組資料想解決的問題如何評估
#     音樂特徵－count.Standard Deviation Value.
#                 mean.Max.min.25%.50%.75%

# %% [markdown]
# [Hw3]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     假設：已知熱門載客點
#     提升業績：載客時間多於等待時間，載客目的地與熱門載客點距離短
# 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     客人目的地，所經每個載客點的等待時間長度
#     資料來源：計程車時間戳記
# 3.蒐集而來的資料型態為何
#     數值：目的地、等待時間、頻率
# 4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     隨機載客與分析後載客比較－等待時間與載客時間
